# %% [markdown]
# <a href="https://colab.research.google.com/github/maksingh91/llmpractice/blob/featurefirstbranch/colab_first_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def multiply(a, b):
    return a * b

result = multiply(5, 6)
print(f"The result of multiplication is =====###@@@!!! {result}")
# Out:
# The result of multiplication is 30

# %%
print("hello world")

name ="John Doe"
age = 30
print(f"My name is {name} and I am {age} years old.")
# Out:
# hello world
# My name is John Doe and I am 30 years old.

# %%
# !git clone https://github.com/maksingh91/llmpractice.git
# Out:
# Cloning into 'llmpractice'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 39 (delta 19), reused 22 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (39/39), 11.23 KiB | 1.87 MiB/s, done.
# Resolving deltas: 100% (19/19), done.

# %%
# %cd llmpractice

# %%
# !git checkout featurefirstbranch
# Out:
# Branch 'featurefirstbranch' set up to track remote branch 'featurefirstbranch' from 'origin'.
# Switched to a new branch 'featurefirstbranch'

# %%
# !python intro_transformers.py
# Out:
# 2025-06-04 15:19:24.684486: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749050364.719116    2749 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749050364.731391    2749 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-04 15:19:24.770022: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# tokenizer_config.json: 100% 26.0/26.0 [00:00<00:00, 118kB/s]
# config.json: 100% 762/762 [00:00<00:00, 3.49MB/s]
# vocab.json: 100% 1.04M/1.04M [00:00<00:00, 12.1MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 15.1MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 16.9MB/s]
# model.safetensors: 100% 353M/353M [00:09<00:00, 37.0MB/s]
# generation_config.json: 100% 124/124 [00:00<00:00, 557kB/s]
# Device set to use cpu
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Once upon a time when the world was becoming more chaotic, the only way to keep things going was to be a much more direct approach to the world.
# "I remember a lot of the things we were thinking about when we were getting started: What do you think of a more direct approach to the world? What do you think of the world as being? When we were in a very primitive state, it was very difficult to do that. But we were able to do it, and we did it at the same time. You can't have a direct approach to the world in any other way. But it was a very simple way to get around it. I actually found that even when you don't have direct, it's rather difficult to really do what you're doing. You don't have direct access to the world. So the more you're doing it, the more likely it is to be taken advantage of by others. And I didn't think of anyone as a person who can actually do that, but you can't really do that without having to do something."
# You have worked on the series of novels, as well as The Dark Knight, The King of the Rings, and The Last Knight.
# You've written a number of books on the series and been involved
